# %%
from cobaya.yaml import yaml_load_file

info_from_yaml = yaml_load_file("lrange_test.yaml")

# %%
from cobaya.run import run

updated_info, sampler = run(info_from_yaml)
# Out:
#  2020-06-22 00:02:53,085 [outputdummy] No output requested. Doing nothing.
#  2020-06-22 00:02:53,126 [run] Input info updated with defaults (dumped to YAML):
# theory:
#   classy:
#     path: null
#     speed: 0.2
#     stop_at_error: false
#     extra_args:
#       non linear: hmcode
#       hmcode_min_k_max: 20
#       N_ncdm: 1
#       N_ur: 2.0328
#     use_renames: false
#     renames:
#       As: A_s
#       ns: n_s
#       nrun: alpha_s
#       nrunrun: beta_s
#       nt: n_t
#       ntrun: alpha_t
#       rdrag: rs_drag
#       omegak: Omega_k
#       omegal: Omega_Lambda
#       w: w0_fld
#       wa: wa_fld
#       omegabh2: omega_b
#       omegab: Omega_b
#       omegach2: omega_cdm
#       omegac: Omega_cdm
#       omegam: Omega_m
#       omegan: Omega_nu
#       tau: tau_reio
#       zrei: z_reio
#       deltazrei: reionization_width
#       helium_redshift: helium_fullreio_redshift
#       helium_delta_redshift: helium_fullreio_width
#       yhe: YHe
# ...

# %%
import clik

# %%
CMBlkl = clik.clik("/home/davidvng/cosmology/modules/data/planck_2018/baseline/plc_3.0/hi_l/plik/plik_rd12_HM_v22b_TTTEEE.clik")

# %%
CMBlkl.get_lmax()
# Out:
# (2508, 2508, -1, 2508, -1, -1)
